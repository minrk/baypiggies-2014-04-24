# %% [markdown]
# # Using Parallel Magics

# %% [markdown]
# IPython has a few magics for working with your engines.
#
# This assumes you have started an IPython cluster, either with the notebook interface,
# or the `ipcluster/controller/engine` commands.

# %%
from IPython import parallel
rc = parallel.Client()
dv = rc[:]
rc.ids
# Out:
# [0, 1, 2, 3]

# %% [markdown]
# Creating a Client registers the parallel magics `%px`, `%%px`, `%pxresult`, `pxconfig`, and `%autopx`.
# These magics are initially associated with a DirectView always associated with all currently registered engines.

# %% [markdown]
# Now we can execute code remotely with `%px`:

# %%
# %px a=5

# %%
# %px print a
# Out:
# [stdout:0] 5
# [stdout:1] 5
# [stdout:2] 5
# [stdout:3] 5

# %%
# %px a
# Out:
# Out[0:3]: 5
# Out[1:3]: 5
# Out[2:3]: 5
# Out[3:3]: 5

# %%
with dv.sync_imports():
    import sys
# Out:
# importing sys on engine(s)

# %%
# %px print >> sys.stderr, "ERROR"
# Out:
# [stderr:0] ERROR
# [stderr:1] ERROR
# [stderr:2] ERROR
# [stderr:3] ERROR

# %% [markdown]
# You don't have to wait for results.  The `%pxconfig` magic lets you change the default blocking/targets for the `%px` magics:

# %%
# %pxconfig --noblock

# %%
# %px import time
# %px time.sleep(5)
# %px time.time()
# Out:
# <AsyncResult: execute>

# %% [markdown]
# But you will notice that this didn't output the result of the last command.
# For this, we have `%pxresult`, which displays the output of the latest request:

# %%
# %pxresult
# Out:
# Out[0:7]: 1398370446.459173
# Out[1:7]: 1398370446.464466
# Out[2:7]: 1398370446.464175
# Out[3:7]: 1398370446.459178

# %% [markdown]
# Remember, an IPython engine is IPython, so you can do magics remotely as well!

# %%
# %%px  --block
# %matplotlib inline
# import numpy as np
# import matplotlib.pyplot as plt

# %% [markdown]
# `%%px` can also be used as a cell magic, for submitting whole blocks.
# This one acceps `--block` and `--noblock` flags to specify
# the blocking behavior, though the default is unchanged.

# %%
dv.scatter('id', dv.targets, flatten=True)
dv['stride'] = len(dv)

# %%
# %%px --block
# print "    id=%s" % id
# print "stride=%s" % stride
# Out:
# [stdout:0]
#     id=0
# stride=4
# [stdout:1]
#     id=1
# stride=4
# [stdout:2]
#     id=2
# stride=4
# [stdout:3]
#     id=3
# stride=4

# %%
# %%px --noblock
# x = np.linspace(0,np.pi,1000)
# for n in range(id, 12, stride):
#     print n
#     plt.plot(x,np.sin(n*x))
# plt.title("Plot %i" % id);
# Out:
# <AsyncResult: execute>

# %%
# %pxresult
# Out:
# [stdout:0]
# 0
# 4
# 8
# [stdout:1]
# 1
# 5
# 9
# [stdout:2]
# 2
# 6
# 10
# [stdout:3]
# 3
# 7
# 11
# [output:0]
# [output:1]
# [output:2]
# [output:3]

# %% [markdown]
# ## Parallel Exceptions

# %% [markdown]
# When you raise exceptions with the parallel exception,
# the CompositeError raised locally will display your remote traceback.

# %%
# %pxconfig --block

# %%
# %%px
# from numpy.random import random
# A = random((100,100,'invalid shape'))
# Out:
# [0:execute]:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)<ipython-input-16-2f86496ae392> in <module>()
#       1 from numpy.random import random
# ----> 2 A = random((100,100,'invalid shape'))
# /Users/minrk/dev/py/numpy/numpy/random/mtrand.so in mtrand.RandomState.random_sample (numpy/random/mtrand/mtrand.c:6950)()
# /Users/minrk/dev/py/numpy/numpy/random/mtrand.so in mtrand.cont0_array (numpy/random/mtrand/mtrand.c:1771)()
# TypeError: an integer is required
#
# [1:execute]:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)<ipython-input-16-2f86496ae392> in <module>()
#       1 from numpy.random import random
# ----> 2 A = random((100,100,'invalid shape'))
# /Users/minrk/dev/py/numpy/numpy/random/mtrand.so in mtrand.RandomState.random_sample (numpy/random/mtrand/mtrand.c:6950)()
# /Users/minrk/dev/py/numpy/numpy/random/mtrand.so in mtrand.cont0_array (numpy/random/mtrand/mtrand.c:1771)()
# TypeError: an integer is required
#
# [2:execute]:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)<ipython-input-16-2f86496ae392> in <module>()
#       1 from numpy.random import random
# ----> 2 A = random((100,100,'invalid shape'))
# /Users/minrk/dev/py/numpy/numpy/random/mtrand.so in mtrand.RandomState.random_sample (numpy/random/mtrand/mtrand.c:6950)()
# /Users/minrk/dev/py/numpy/numpy/random/mtrand.so in mtrand.cont0_array (numpy/random/mtrand/mtrand.c:1771)()
# TypeError: an integer is required
#
# [3:execute]:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)<ipython-input-16-2f86496ae392> in <module>()
#       1 from numpy.random import random
# ----> 2 A = random((100,100,'invalid shape'))
# /Users/minrk/dev/py/numpy/numpy/random/mtrand.so in mtrand.RandomState.random_sample (numpy/random/mtrand/mtrand.c:6950)()
# /Users/minrk/dev/py/numpy/numpy/random/mtrand.so in mtrand.cont0_array (numpy/random/mtrand/mtrand.c:1771)()
# TypeError: an integer is required

# %% [markdown]
# ## Remote Cell Magics

# %% [markdown]
# Remember, Engines are IPython too, so the cell that is run remotely by %%px can in turn use a cell magic.

# %%
# %%px
# %%bash
# echo "remote parallel interactive bash!"
# hostname
# date
# echo $$
# Out:
# [stdout:0]
# remote parallel interactive bash!
# Horus.local
# Thu Apr 24 13:15:14 PDT 2014
# 46317
# [stdout:1]
# remote parallel interactive bash!
# Horus.local
# Thu Apr 24 13:15:14 PDT 2014
# 46318
# [stdout:2]
# remote parallel interactive bash!
# Horus.local
# Thu Apr 24 13:15:14 PDT 2014
# 46319
# [stdout:3]
# remote parallel interactive bash!
# Horus.local
# Thu Apr 24 13:15:14 PDT 2014
# 46320

# %%
# %%px
# %%ruby
# puts 'hello from ruby'
# Out:
# [stdout:0] hello from ruby
# [stdout:1] hello from ruby
# [stdout:2] hello from ruby
# [stdout:3] hello from ruby

# %%
dv.scatter('rank', dv.targets, flatten=True)
# Out:
# <AsyncResult: scatter>

# %%
# %%px
# %%timeit
# from numpy.random import random
# from numpy.linalg import norm
# N = 100 * (rank + 1)
# A = random((N,N))
# norm(A, 2)
# Out:
# [stdout:0] 1000 loops, best of 3: 1.06 ms per loop
# [stdout:1] 100 loops, best of 3: 8.67 ms per loop
# [stdout:2] 10 loops, best of 3: 32.2 ms per loop
# [stdout:3] 10 loops, best of 3: 56.1 ms per loop
